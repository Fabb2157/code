# %%
import math
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('C:/Users/EL FASHKA/Desktop/FABB/conso.csv', sep = ";")
df
# Out:
#              Date Heures  Consommation  Prévision J-1  Prévision J  Solaire
# 0      01/01/2019  00:00         64267          64200        63800       -2
# 1      01/01/2019  00:30         63209          62700        62200       -2
# 2      01/01/2019  01:00         60968          60500        60200       -2
# 3      01/01/2019  01:30         60772          61100        60900       -2
# 4      01/01/2019  02:00         60164          60800        60400       -2
# ...           ...    ...           ...            ...          ...      ...
# 35006  31/12/2019  23:00         66765          67500        68900       -1
# 35007  31/12/2019  23:15             0          67500        68850        0
# 35008  31/12/2019  23:30         66520          67500        68800       -1
# 35009  31/12/2019  23:45             0          67750        68400        0
# 35010  31/12/2019  00:00             0              0            0        0
#
# [35011 rows x 6 columns]

# %%
plt.figure(figsize=(32,16))
plt.title('Energy')
plt.plot( df['Consommation'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Energy Conso 2019', fontsize=18)
plt.show()

# %%
data = df.filter(['Consommation'])
dataset = data.values
training_data_len = math.ceil(len(dataset)*.8)
training_data_len
# Out:
# 28009

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)
scaled_data
# Out:
# array([[0.72659129],
#        [0.71462973],
#        [0.68929339],
#        ...,
#        [0.75206331],
#        [0.        ],
#        [0.        ]])

# %%
train_data = scaled_data[0:training_data_len, :]
x_train = []
y_train = []
for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])
    if i <= 61:
        print(x_train)
        print(y_train)
        print()
# Out:
# [array([0.72659129, 0.71462973, 0.68929339, 0.68707744, 0.6802035 ,
#        0.67247032, 0.64942906, 0.63191634, 0.61444884, 0.60569813,
#        0.59787451, 0.60079141, 0.59773884, 0.60459016, 0.60373092,
#        0.60662521, 0.60775579, 0.60356133, 0.60360656, 0.61193895,
#        0.62157151, 0.63226682, 0.64286037, 0.65588468, 0.66858112,
#        0.68429621, 0.6988355 , 0.68627473, 0.67429056, 0.66428491,
#        0.65200678, 0.        , 0.64864895, 0.        , 0.64384398,
#        0.        , 0.6454381 , 0.        , 0.65187111, 0.        ,
#        0.67597513, 0.        , 0.70018089, 0.        , 0.71518372,
#        0.        , 0.72572075, 0.        , 0.72903335, 0.        ,
#        0.72533635, 0.        , 0.7149576 , 0.        , 0.70239683,
#        0.        , 0.68944036, 0.        , 0.67780667, 0.        ])]
# [0.6854946297343132]
#
# [array([0.72659129, 0.71462973, 0.68929339, 0.68707744, 0.6802035 ,
#        0.67247032, 0.64942906, 0.63191634, 0.61444884, 0.60569813,
#        0.59787451, 0.60079141, 0.59773884, 0.60459016, 0.60373092,
#        0.60662521, 0.60775579, 0.60356133, 0.60360656, 0.61193895,
#        0.62157151, 0.63226682, 0.64286037, 0.65588468, 0.66858112,
#        0.68429621, 0.6988355 , 0.68627473, 0.67429056, 0.66428491,
#        0.65200678, 0.        , 0.64864895, 0.        , 0.64384398,
#        0.        , 0.6454381 , 0.        , 0.65187111, 0.        ,
#        0.67597513, 0.        , 0.70018089, 0.        , 0.71518372,
#        0.        , 0.72572075, 0.        , 0.72903335, 0.        ,
#        0.72533635, 0.        , 0.7149576 , 0.        , 0.70239683,
#        0.        , 0.68944036, 0.        , 0.67780667, 0.        ]), array([0.71462973, 0.68929339, 0.68707744, 0.6802035 , 0.67247032,
#        0.64942906, 0.63191634, 0.61444884, 0.60569813, 0.59787451,
#        0.60079141, 0.59773884, 0.60459016, 0.60373092, 0.60662521,
#        0.60775579, 0.60356133, 0.60360656, 0.61193895, 0.62157151,
#        0.63226682, 0.64286037, 0.65588468, 0.66858112, 0.68429621,
#        0.6988355 , 0.68627473, 0.67429056, 0.66428491, 0.65200678,
#        0.        , 0.64864895, 0.        , 0.64384398, 0.        ,
#        0.6454381 , 0.        , 0.65187111, 0.        , 0.67597513,
#        0.        , 0.70018089, 0.        , 0.71518372, 0.        ,
#        0.72572075, 0.        , 0.72903335, 0.        , 0.72533635,
#        0.        , 0.7149576 , 0.        , 0.70239683, 0.        ,
#        0.68944036, 0.        , 0.67780667, 0.        , 0.68549463])]
# [0.6854946297343132, 0.0]

# %%
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train = np.reshape(x_train,(x_train.shape[0], x_train.shape[1], 1))
x_train.shape
# Out:
# (27949, 60, 1)

# %%
model = Sequential()
model.add(LSTM(50, return_sequences = True, input_shape= (x_train.shape[1], 1)))
model.add(LSTM(50, return_sequences = False))
model.add(Dense(25))
model.add(Dense(1))

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
model.fit(x_train, y_train, batch_size=1, epochs=1)
# Out:
# WARNING:tensorflow:From C:\Users\EL FASHKA\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/1
# 27949/27949 [==============================] - 1110s 40ms/step - loss: 0.0025

# %%
test_data = scaled_data[training_data_len - 60:, :]
x_test = []
y_test =dataset [training_data_len:, :]
for i in range(60, len(test_data)):
    x_test.append(test_data[i - 60:i, 0])

# %%
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
x_test.shape
# Out:
# (7002, 60, 1)

# %%
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)

# %%
rmse = np.sqrt(np.mean(predictions - y_test)**2)
rmse
# Out:
# 1458.9349610431982

# %%
train = data[:training_data_len]
valid = data [training_data_len:]
valid['Predictions'] = predictions
plt.figure(figsize=(32,16))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Energy Conso 2019', fontsize=18)
plt.plot( train['Consommation'])
plt.plot( valid[['Consommation', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc= 'lower right')
plt.show()
# Out:
# C:\Users\EL FASHKA\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
valid
# Out:
#        Consommation   Predictions
# 28009             0   -503.113861
# 28010         41114  38868.882812
# 28011             0   -287.061432
# 28012         40079  38405.476562
# 28013             0   -244.885178
# ...             ...           ...
# 35006         66765  61022.195312
# 35007             0    142.282227
# 35008         66520  65719.398438
# 35009             0    352.573639
# 35010             0  63216.019531
#
# [7002 rows x 2 columns]
